# %% [markdown]
# <a href="https://colab.research.google.com/github/GTD2101-ACD-AB-EJ23/03-pandas-20170810/blob/main/05.%20DataMissing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tipos de Datos y Valores Extraviados
#
# En este JNB se revisará el tema de Tipos de Datos y Valores Extraviados en Pandas.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd

# %%
#https://raw.githubusercontent.com/GTD2101-ACD-AB-EJ23/03-pandas-VBatiz/main/data/winemag-data-130k-v2.csv
reviews = pd.read_csv("https://raw.githubusercontent.com/GTD2101-ACD-AB-EJ23/03-pandas-VBatiz/main/data/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews.points.dtype
# Out:
# dtype('int64')

# %%
reviews.country.dtype
# Out:
# dtype('O')

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# ###Valores nulos

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ###Sustituyendo valores nulos en un campo

# %%
reviews2 = reviews.country.fillna("No Country")

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle
# Out:
# 0         @kerinokeefe
# 1           @vossroger
# 2          @paulgwine
# 3                  NaN
# 4          @paulgwine
#               ...
# 129966             NaN
# 129967     @paulgwine
# 129968      @vossroger
# 129969      @vossroger
# 129970      @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews2
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.country[pd.isnull(reviews.country)] = "Unknown"
# Out:
# <ipython-input-14-9405ea2931ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.country[pd.isnull(reviews.country)] = "Unknown"

# %%
reviews[reviews.country == "Unknown"]
# Out:
#         country                                        description  \
# 913     Unknown  Amber in color, this wine has aromas of peach ...
# 3131    Unknown  Soft, fruity and juicy, this is a pleasant, si...
# 4243    Unknown  Violet-red in color, this semisweet wine has a...
# 9509    Unknown  This mouthwatering blend starts with a nose of...
# 9750    Unknown  This orange-style wine has a cloudy yellow-gol...
# ...         ...                                                ...
# 124176  Unknown  This Swiss red blend is composed of four varie...
# 129407  Unknown  Dry spicy aromas of dusty plum and tomato add ...
# 129408  Unknown  El Capricho is one of Uruguay's more consisten...
# 129590  Unknown  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900  Unknown  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews[pd.isnull(reviews.country)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []
